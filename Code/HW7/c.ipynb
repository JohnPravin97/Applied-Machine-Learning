# %% [markdown]
# **NOT WORKING**

# %%
pip install logitboost
# Out:
# Collecting logitboost
#   Downloading https://files.pythonhosted.org/packages/76/d8/e0606b2ec488ccafbcf0a3d008ad709609ba8ce026aeafa115f513e54611/logitboost-0.7-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from logitboost) (1.18.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from logitboost) (0.22.2.post1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from logitboost) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->logitboost) (0.16.0)
# Installing collected packages: logitboost
# Successfully installed logitboost-0.7

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler 
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import log_loss
import matplotlib.pyplot as plt
from logitboost import LogitBoost

# %%
X_train = pd.read_csv("madelon_train.data",sep=' ',header=None)
y_train = pd.read_csv("madelon_train.labels",header=None)
X_train.dropna(axis=1,how='all',inplace=True)
X_test = pd.read_csv("madelon_valid.data",sep=' ',header=None)
y_test = pd.read_csv("madelon_valid.labels",header=None)
X_test.dropna(axis=1,how='all',inplace=True)

# %%
ss=StandardScaler()
ss.fit(X_train)
tf_X_train=ss.transform(X_train)
tf_X_test=ss.transform(X_test)
y_train=y_train.replace(-1,0)
y_test=y_test.replace(-1,0)

# %%
temp = np.array(y_train)
y_train = np.concatenate(temp)

# %%
klist = [10, 30, 100, 300, 500]
missclassif_trainlist,missclassif_testlist=[],[]
for k in klist:
  lb = LogitBoost(base_estimator=None, n_estimators=k, weight_trim_quantile=0.05, max_response=4.0, learning_rate=1.0, bootstrap=False, random_state=None)
  lb.fit(tf_X_train,y_train)
  y_pred_train = lb.predict(tf_X_train)
  y_pred_test = lb.predict(tf_X_test)
  missclassif_trainlist.append((1-accuracy_score(y_train,y_pred_train.T))*2000)
  missclassif_testlist.append((1-accuracy_score(y_test, y_pred_test.T))*600)
print(missclassif_trainlist, missclassif_testlist)
# Out:
# [701.0000000000001, 548.0, 322.99999999999994, 48.00000000000004, 2.9999999999998916] [237.0, 226.00000000000003, 240.0, 240.0, 223.00000000000003]

# %%
temp1 = np.array(missclassif_trainlist)
temp1 = temp1/2000
training_error = temp1*100
temp2 = np.array(missclassif_testlist)
temp2 = temp2/600
test_error = temp2*100

# %%
training_error
# Out:
# array([35.05, 27.4 , 16.15,  2.4 ,  0.15])

# %%
test_error
# Out:
# array([39.5       , 37.66666667, 40.        , 40.        , 37.16666667])

# %%
lb = LogitBoost(base_estimator=None, n_estimators=10, weight_trim_quantile=0.05, max_response=4.0, learning_rate=1.0, bootstrap=False, random_state=None)

# %%
lb.fit(X_train,y_train)
# Out:
# LogitBoost(base_estimator=None, bootstrap=False, learning_rate=1.0,
#            max_response=4.0, n_estimators=10, random_state=None,
#            weight_trim_quantile=0.05)

# %%
lol=lb.predict(X_test)

# %%
(1-(accuracy_score(y_test,lol)))*600
# Out:
# 237.0
